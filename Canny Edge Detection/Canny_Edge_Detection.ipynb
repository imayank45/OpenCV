# %%
import cv2
import matplotlib.pyplot as plt

# %%
# read the image
img = cv2.imread('/content/rohit-sharma.jpg')

# %%
# display image
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray,cmap='gray')

# %%
blur = cv2.GaussianBlur(gray,(5,5),0)
plt.imshow(blur)

# %%
canny = cv2.Canny(blur,10,150)
plt.imshow(canny)

# %%
#
import cv2

import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread("/content/rohit-sharma.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect edges using Canny
edges = cv2.Canny(gray, 50, 150)

# Find contours
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Draw contours on the original image
cv2.drawContours(image, contours, -1, (0, 255, 0), 2)

# Show the result
plt.figure(figsize=(10,5))
plt.subplot(1,2,1), plt.imshow(edges, cmap='gray'), plt.title("Canny Edges")
plt.subplot(1,2,2), plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)), plt.title("Contours Detected")
plt.show()
